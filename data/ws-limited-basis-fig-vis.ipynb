# %%
import os
import utils
import glob
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import ImageGrid
from matplotlib import cm


for file in glob.glob("testing/ws-limited-basis-fig/*/*/*.bin"):
    file = file.replace("\\","/")
    utils.plot_prior(file, plt.gca())
    plt.axis("off")
    kernel = file.split("/")[2]
    plt.savefig(f"figures/ws-limited-basis-{kernel}-{os.path.basename(file)[:-4]}.pdf", bbox_inches='tight',pad_inches = 0, dpi = 300)
    plt.show()
