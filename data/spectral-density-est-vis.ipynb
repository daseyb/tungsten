# %%
import os
import utils
import glob
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import ImageGrid
from matplotlib import cm
import matplotlib.patches as patches


path = "testing/spectral-density-est/"


for file in glob.glob(path + "*/*/discrete-spectral-density.bin"):
    dspec = np.fromfile(file)
    aspec = np.fromfile(file.replace("discrete", "analytic"))

    ts = np.linspace(0, 10, dspec.shape[0])
    plt.plot(ts, dspec)
    plt.plot(ts, aspec)
